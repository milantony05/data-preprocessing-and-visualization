# %%
if 5 > 2:
    print("Five is greater than two!")
# Out:
# Five is greater than two!

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
name = input("Enter your name: ")
print("Hello, " + name + "!")
age = int(input("Enter your age: "))
# Out:
# Hello, Milan!

# %%
# Integer assignment
age = 45

# Floating-point assignment
salary = 1456.8

# String assignment
name = "MIT"

print(age)
print(salary)
print(name)
# Out:
# 45
# 1456.8
# MIT

# %%
# Data Types
x = "Hello World" # string
Y = 50 # integer
Z = 60.5 # float
A = 3j # complex
B = ["RAM", "ROB", "RAC"] # list
C = ("RAM", "ROB", "RAC") # tuple
D = {"name": "Suraj", "age": 24} # dict
E = {"abc", "for", "xyz"} # set
F = True # bool
print(x)
print(Y)
print(Z)
print(A)
print(B)
print(C)
print(D)
print(E)
print(F)

# integer variable.
a = 100
print("The type of variable having value", a, " is ", type(a))

# float variable.
c = 20.345
print("The type of variable having value", c, " is ", type(c))
# Out:
# Hello World
# 50
# 60.5
# 3j
# ['RAM', 'ROB', 'RAC']
# ('RAM', 'ROB', 'RAC')
# {'name': 'Suraj', 'age': 24}
# {'for', 'abc', 'xyz'}
# True
# The type of variable having value 100  is  <class 'int'>
# The type of variable having value 20.345  is  <class 'float'>

# %%
li = [ 'abcd', 786 , 2.23, 'john', 70.2 ] # creating list without constructor
tinylist = [123, 'john']

print(li) # Prints complete list
print(li[0]) # Prints first element of the list
print(li[1:3]) # list slicing, Prints elements starting from 2nd till 3rd
print(li[2:]) # Prints elements starting from 3rd element
print(tinylist * 2) # Prints list two times
print(li + tinylist) # Prints concatenated lists
print(len(li)) # Print the number of items in the list
print(type(li)) # lists are defined as objects with the data type 'list'
li[-1] # negative indexing prints from last
li[-2]
# Out:
# ['abcd', 786, 2.23, 'john', 70.2]
# abcd
# [786, 2.23]
# [2.23, 'john', 70.2]
# [123, 'john', 123, 'john']
# ['abcd', 786, 2.23, 'john', 70.2, 123, 'john']
# 5
# <class 'list'>
# 'john'

# %%
# list can also be created using list() constructor
a = list((1, 2, 3, 'apple', 4.5))
print(a)
# Out:
# [1, 2, 3, 'apple', 4.5]

# %%
# creating list using range function
L=list(range(0,6))
print(L)
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
cities = ['Delhi', 'Mumbai' , 'Bangalore']
temperatures = [32, 30, 28, 35]

# 1.
all_data = cities + temperatures
print(all_data)

#2.
cities_twice = cities * 2
print(cities_twice)

#3.
print("Length of temperatures:", len(temperatures))

#4.
print("Max of temperatures:", max(temperatures))
print("Min of temperatures:", min(temperatures))
print("Sum of temperatures:", sum(temperatures))

#5.
cities.append('Chennai')
print(cities)

#6.
cities.insert(1, 'Hyderabad')
print(cities)

#7.
cities.remove('Mumbai')
print(cities)

#8.
removed_city = cities.pop()
print(cities)

#9.
cities.reverse()
print(cities)

#10.
temperatures.sort(reverse=True)
print(temperatures)
# Out:
# ['Delhi', 'Mumbai', 'Bangalore', 32, 30, 28, 35]
# ['Delhi', 'Mumbai', 'Bangalore', 'Delhi', 'Mumbai', 'Bangalore']
# Length of temperatures: 4
# Max of temperatures: 35
# Min of temperatures: 28
# Sum of temperatures: 125
# ['Delhi', 'Mumbai', 'Bangalore', 'Chennai']
# ['Delhi', 'Hyderabad', 'Mumbai', 'Bangalore', 'Chennai']
# ['Delhi', 'Hyderabad', 'Bangalore', 'Chennai']
# ['Delhi', 'Hyderabad', 'Bangalore']
# ['Bangalore', 'Hyderabad', 'Delhi']
# [35, 32, 30, 28]

# %%
tup = ()
print(tup)
tup=(5,)
print(tup)

# Using String
tup = ('MIT', 'BLR')
print(tup)

# Using List
li = [1, 2, 4, 5, 6]
print(tuple(li))

# Using Built-in Function/ using constructor
tup6 = tuple('MAHE')
print(tup6)
# Out:
# ()
# (5,)
# ('MIT', 'BLR')
# (1, 2, 4, 5, 6)
# ('M', 'A', 'H', 'E')

# %%
# Creating a Tuple with Mixed Datatypes.
t = (5, 'Welcome', 7, 'Data Science')
print(t)

# Creating a Tuple with nested tuples
tup1 = (0, 1, 2, 3)
tup2 = ('python', 'Lab')
tup3 = (tup1, tup2)
print(tup3)

# Creating a Tuple with repetition
tup1 = ('DPV',) * 3
print(tup1)
# Out:
# (5, 'Welcome', 7, 'Data Science')
# ((0, 1, 2, 3), ('python', 'Lab'))
# ('DPV', 'DPV', 'DPV')

# %%
tu = ( 'abcd', 786 , 2.23, 'john', 70.2 )
tinytuple = (123, 'john')

print(tu) # Prints the complete tuple
print(tu[0]) # Prints first element of the tuple
print(tu[1:3]) # Prints elements of the tuple starting from 2nd till 3rd
print(tu[2:]) # Prints elements of the tuple starting from 3rd element
print(tinytuple * 2) # Prints the contents of the tuple twice
print(tu + tinytuple) # Prints concatenated tuples
# Out:
# ('abcd', 786, 2.23, 'john', 70.2)
# abcd
# (786, 2.23)
# (2.23, 'john', 70.2)
# (123, 'john', 123, 'john')
# ('abcd', 786, 2.23, 'john', 70.2, 123, 'john')

# %%
thisdict = {
    "brand": "Ford",
    "model": "Mustang",
    "year": 1964
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
thisdict = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}
print(thisdict["brand"])
# Out:
# Ford

# %%
set1 = {1, 2, 3, 4}
print(set1)
# Out:
# {1, 2, 3, 4}

# %%
# using set()
set1 = set()
print(set1)

#it removes duplicates and keeps only unique characters and Sets do not maintain the order
set1 = set("DataPreprocessing")
print(set1)

# Creating a Set with the use of a List
set1 = set(["SOCE", "MIT", "MAHE"])
print(set1)

# Creating a Set with the use of a tuple
tup = ("SOCE", "DataScience", "BLR")
print(set(tup))

# Creating a Set with the use of a dictionary
d = {"DataScience": 1, "Cyb": 2, "IT": 3}#when a dictionary is passed to a function like set
print(set(d))
# Out:
# set()
# {'P', 'c', 'g', 'a', 's', 'r', 'n', 'p', 'o', 'D', 't', 'i', 'e'}
# {'MAHE', 'MIT', 'SOCE'}
# {'DataScience', 'BLR', 'SOCE'}
# {'Cyb', 'DataScience', 'IT'}

# %%
age = 70
is_member = True

if age >= 60:
    if is_member:
        print("30% senior discount!")
    else:
        print("20% senior discount.")
else:
    print("Not eligible for a senior discount.")

age = 25

if age <= 12:
    print("Child.")
elif age <= 19:
    print("Teenager.")
elif age <= 35:
    print("Young adult.")
else:
    print("Adult.")
# Out:
# 30% senior discount!
# Young adult.

# %%
n = 4
for i in range(0, n):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
MAHE= ["MIT", "SMI", "DLHS"] #list
for x in MAHE:
    print(x)

MAHE= ("MIT", "SMI", "DLHS") #tuple
for x in MAHE:
    print(x)

MAHE = "MANIPAL" #strings
for x in MAHE:
    print(x)

MA = ["DS", "IT", "Cyb"] # Iterating by the Index of Sequences
for index in range(len(MA)):
    print(MA[index])

#break
MAHE = ["MIT", "SMI", "DLHS"]
for x in MAHE:
    print(x)
    if x == "SMI":
        break

#continue
MAHE = ["MIT", "SMI", "DLHS"]
for x in MAHE:
    if x == "SMI":
        continue
    print(x)

#range()
for x in range(6):
    print(x)
# Out:
# MIT
# SMI
# DLHS
# MIT
# SMI
# DLHS
# M
# A
# N
# I
# P
# A
# L
# DS
# IT
# Cyb
# MIT
# SMI
# MIT
# DLHS
# 0
# 1
# 2
# 3
# 4
# 5

# %%
# nested for loop

adj = ["r", "b", "t"]
fruits = ["a", "b", "c"]

for x in adj:
    for y in fruits:
        print(x, y)
# Out:
# r a
# r b
# r c
# b a
# b b
# b c
# t a
# t b
# t c

# %%
i = 1
while i < 6:
    print(i)
    i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# using continue, Prints all letters except 'e' and 's'
i = 0
a = 'datapreprocessing'
while i < len(a):
    if a[i] == 'e' or a[i] == 's':
        i += 1
        continue
    print(a[i])
    i += 1
# Out:
# d
# a
# t
# a
# p
# r
# p
# r
# o
# c
# i
# n
# g

# %%
# break the loop as soon it sees 'e' or 's'
i = 0
a = 'datapreprocessing'
while i < len(a):
    if a[i] == 'e' or a[i] == 's':
        i += 1
        break
    print(a[i])
    i += 1
# Out:
# d
# a
# t
# a
# p
# r

# %%
# creating function with def keyword
def my_function():
    print("Hello from a function")

# calling function
my_function()
# Out:
# Hello from a function

# %%
# with arguments
def my_function(fname):
    print(fname + " course")

my_function("Java")
my_function("DS")
my_function("AIML")
# Out:
# Java course
# DS course
# AIML course

# %%
# If the number of arguments is unknown, add a * before the parameter name:
def my_function(*fname):
    print("The simple couse is " + fname[2])

my_function("DS", "AIML", "DAA")
# Out:
# The simple couse is DAA

# %%
# Program to print positive, negative values
def sign(x):
    if x > 0:
        return 'positive'
    elif x < 0:
        return 'negative'
    else:
        return 'zero'
for x in [-1, 0, 1]:
    print(sign(x))
# Out:
# negative
# zero
# positive

# %%
def hello(name, loud=False):
    if loud:
        print('HELLO, {}'.format(name.upper()))
    else:
        print('Hello, {}!'.format(name))

hello('XYZ')
hello('Abc', loud=True)
# Out:
# Hello, XYZ!
# HELLO, ABC

# %%
def add(x, y):
    return x + y
    
def subtract(x, y):
    return x - y
    
def multiply(x, y):
    return x * y
    
def divide(x, y):
    return x / y
    
print("Select operation.")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")

while True:
    choice = input("Enter choice(1/2/3/4): ")
    
    if choice in ('1', '2', '3', '4'):
        try:
            num1 = float(input("Enter first number: "))
            num2 = float(input("Enter second number: "))
        except ValueError:
            print("Invalid input. Please enter a number.")
            continue
            
        if choice == '1':
            print(num1, "+", num2, "=", add(num1, num2))
            
        elif choice == '2':
            print(num1, "-", num2, "=", subtract(num1, num2))
            
        elif choice == '3':
            print(num1, "*", num2, "=", multiply(num1, num2))
            
        elif choice == '4':
            print(num1, "/", num2, "=", divide(num1, num2))

        next_calculation = input("Let's do next calculation? (yes/no): ")
        if next_calculation == "no":
          break
    else:
        print("Invalid Input")
# Out:
# Select operation.
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# 2.0 + 4.0 = 6.0
# 5.0 / 7.0 = 0.7142857142857143

# %%
class Greeter:
    def __init__(self, name):
        self.name = name
    def greet(self, loud=False):
        if loud:
            print('HELLO, {}'.format(self.name.upper()))
        else:
            print('Hello, {}!'.format(self.name))
g = Greeter('Fred')
g.greet()
g.greet(loud=True)
# Out:
# Hello, Fred!
# HELLO, FRED
